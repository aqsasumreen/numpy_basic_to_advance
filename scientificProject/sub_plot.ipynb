# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y =[1,2,3,4,5]
# subplot in sb differentdraphs ko aik hi chart me show kry ga, position 1,2,3,4 vary kry gi
plt.subplot(2,2,1)
plt.plot(x,y) # linear plot
plt.subplot(2,2,2)
plt.pie([1], colors = 'red') #pie plot
plt.subplot(2,2,3)
plt.pie(x) #2 pie
x1 =[10,20,30,40]
y1 =["a", "b", "c","d"]
plt.subplot(2,2,4)
plt.bar(x1,y1)   
plt.show()
